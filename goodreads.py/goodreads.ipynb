# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('goodreads_library_export.csv')
df.head()
# Out:
#      Book Id                                              Title  \
# 0   63103712  The Only Purple House in Town (Fix-It Witches,...
# 1  199334767                                Same Time Next Year
# 2   53711756                               When Harry Met Harry
# 3  137231760  King of Storms and Feathers: A Dark Fae Fantas...
# 4   40120621                               From Lukov with Love
#
#            Author       Author l-f             Additional Authors  \
# 0     Ann Aguirre     Aguirre, Ann                            NaN
# 1    Tessa Bailey    Bailey, Tessa                            NaN
# 2    Sydney Smyth    Smyth, Sydney  Teddy Hamilton, Malcolm Young
# 3      Juno Heart      Heart, Juno                            NaN
# 4  Mariana Zapata  Zapata, Mariana  Callie Dalton, Teddy Hamilton
#
#             ISBN            ISBN13  My Rating  Average Rating  \
# 0  ="1728262496"  ="9781728262499"          0            3.47
# 1  ="1662517912"  ="9781662517914"          4            3.60
# 2            =""               =""          3            3.51
# 3            =""  ="9780645624267"          0            3.61
# 4            =""               =""          0            4.25
#
#                  Publisher  ...   Date Read  Date Added        Bookshelves  \
# 0   Sourcebooks Casablanca  ...         NaN  2023/10/31  currently-reading
# 1  Amazon Original Stories  ...  2023/12/13  2023/11/26                NaN
# 2        Audible Originals  ...  2023/12/12  2023/11/26                NaN
# 3                      NaN  ...         NaN  2023/12/11            to-read
# 4                      NaN  ...         NaN  2023/12/11            to-read
#
#    Bookshelves with positions    Exclusive Shelf  \
# 0      currently-reading (#5)  currently-reading
# 1                         NaN               read
# 2                         NaN               read
# 3              to-read (#207)            to-read
# 4              to-read (#206)            to-read
#
#                                            My Review Spoiler Private Notes  \
# 0                                                NaN     NaN           NaN
# 1                                                NaN     NaN           NaN
# 2  This book makes me realize how problematic par...     NaN           NaN
# 3                                                NaN     NaN           NaN
# 4                                                NaN     NaN           NaN
#
#   Read Count Owned Copies
# 0          1            0
# 1          1            0
# 2          1            0
# 3          0            0
# 4          0            0
#
# [5 rows x 24 columns]

# %%
df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_').str.replace('-', '_')

df.columns
# Out:
# Index(['book_id', 'title', 'author', 'author_l_f', 'additional_authors',
#        'isbn', 'isbn13', 'my_rating', 'average_rating', 'publisher', 'binding',
#        'number_of_pages', 'year_published', 'original_publication_year',
#        'date_read', 'date_added', 'bookshelves', 'bookshelves_with_positions',
#        'exclusive_shelf', 'my_review', 'spoiler', 'private_notes',
#        'read_count', 'owned_copies'],
#       dtype='object')

# %%
df.describe()
# Out:
#             book_id   my_rating  average_rating  number_of_pages  \
# count  3.870000e+02  387.000000      387.000000       374.000000
# mean   6.448326e+07    2.018088        4.000956       402.149733
# std    3.916631e+07    2.286972        0.311274       141.881739
# min    6.842800e+04    0.000000        3.090000         0.000000
# 25%    5.058528e+07    0.000000        3.790000       338.000000
# 50%    5.806503e+07    0.000000        4.020000       384.000000
# 75%    6.151168e+07    5.000000        4.200000       445.500000
# max    2.015817e+08    5.000000        5.000000      1242.000000
#
#        year_published  original_publication_year  private_notes  read_count  \
# count      385.000000                 358.000000            0.0  387.000000
# mean      2020.797403                2020.539106            NaN    0.475452
# std          2.835874                   2.923369            NaN    0.525310
# min       2006.000000                2006.000000            NaN    0.000000
# 25%       2020.000000                2020.000000            NaN    0.000000
# 50%       2022.000000                2021.000000            NaN    0.000000
# 75%       2023.000000                2022.000000            NaN    1.000000
# max       2024.000000                2024.000000            NaN    3.000000
#
#        owned_copies
# count         387.0
# mean            0.0
# std             0.0
# min             0.0
# 25%             0.0
# 50%             0.0
# 75%             0.0
# max             0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   book_id                     387 non-null    int64
#  1   title                       387 non-null    object
#  2   author                      387 non-null    object
#  3   author_l_f                  387 non-null    object
#  4   additional_authors          30 non-null     object
#  5   isbn                        387 non-null    object
#  6   isbn13                      387 non-null    object
#  7   my_rating                   387 non-null    int64
#  8   average_rating              387 non-null    float64
#  9   publisher                   339 non-null    object
#  10  binding                     385 non-null    object
#  11  number_of_pages             374 non-null    float64
#  12  year_published              385 non-null    float64
#  13  original_publication_year   358 non-null    float64
#  14  date_read                   169 non-null    object
#  15  date_added                  387 non-null    object
#  16  bookshelves                 212 non-null    object
#  17  bookshelves_with_positions  212 non-null    object
#  18  exclusive_shelf             387 non-null    object
#  19  my_review                   36 non-null     object
#  20  spoiler                     3 non-null      object
#  21  private_notes               0 non-null      float64
#  22  read_count                  387 non-null    int64
#  23  owned_copies                387 non-null    int64
# dtypes: float64(5), int64(4), object(15)
# memory usage: 72.7+ KB

# %%
df.shape
# Out:
# (387, 24)
